# %%
import pandas as pd
df = pd.read_csv('datasets/DSAITrader_20210611_114558_4TRAIN.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Columns: 330 entries, dthref to WPR_SINAL_4
# dtypes: float64(328), object(2)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#        ALLI0_CLOSE_0  ALLI0_CLOSE_1  ALLI0_CLOSE_2  ALLI0_CLOSE_3  \
# count     736.000000     736.000000     736.000000     736.000000
# mean       -0.025177      -0.010087       0.016962       0.042777
# std         0.083845       0.102952       0.144278       0.171575
# min        -0.342110      -0.342110      -0.342110      -0.342110
# 25%        -0.076707      -0.073580      -0.069120      -0.060820
# 50%        -0.032200      -0.025520      -0.014045       0.002570
# 75%         0.022010       0.037060       0.063035       0.089665
# max         0.307270       0.549060       0.915930       0.915930
#
#        ALLI0_CLOSE_4  ALLI1_CLOSE_0  ALLI1_CLOSE_1  ALLI1_CLOSE_2  \
# count     736.000000     736.000000     736.000000     736.000000
# mean        0.073063      -0.033170      -0.028382      -0.014500
# std         0.204202       0.084440       0.088259       0.102435
# min        -0.342110      -0.368100      -0.368100      -0.368100
# ...

# %%
y = 'LABEL_CLOSE_10'
df2 = df.drop(['LABEL_SLMIN_10', 'LABEL_TPMAX_SLMIN10'], axis=1)
from ds_utils import getCorrHeatMap
getCorrHeatMap(df2)
# Out:
# <AxesSubplot:>
