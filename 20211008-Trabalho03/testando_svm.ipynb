# %% [markdown]
# # Carregando, limpando e analisando os dados

# %%
import trab03_utils as util
#high house price data set
ds_hhprice = util.getDSPriceHousing_ClassProb()
ds_hhprice.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population  \
# 0                          4.09     23086.800503
# 1                          3.09     40173.072174
# 2                          5.13     36882.159400
# 3                          3.26     34310.242831
# 4                          4.23     26354.109472
#
#                                              Address  high_price
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...       False
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...        True
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...       False
# 3                          USS Barnett\nFPO AP 44820       False
# 4                         USNS Raymond\nFPO AE 09386       False

# %%
ds_hhprice.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population
# count                   5000.000000      5000.000000
# mean                       3.981330     36163.516039
# std                        1.234137      9925.650114
# min                        2.000000       172.610686
# 25%                        3.140000     29403.928702
# 50%                        4.050000     36199.406689
# 75%                        4.490000     42861.290769
# max                        6.500000     69621.713378

# %%
ds_hhprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Address                       5000 non-null   object
#  6   high_price                    5000 non-null   bool
# dtypes: bool(1), float64(5), object(1)
# memory usage: 239.4+ KB

# %%
ds_hhprice.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# high_price                            0.472206             0.325657
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# high_price                                     0.243635
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# Avg. Area Income                                  0.019788        -0.016234
# Avg. Area House Age                               0.006149        -0.018743
# Avg. Area Number of Rooms                         0.462695         0.002040
# Avg. Area Number of Bedrooms                      1.000000        -0.022168
# Area Population                                  -0.022168         1.000000
# high_price                                        0.127658         0.302809
#
#                               high_price
# Avg. Area Income                0.472206
# Avg. Area House Age             0.325657
# Avg. Area Number of Rooms       0.243635
# Avg. Area Number of Bedrooms    0.127658
# Area Population                 0.302809
# high_price                      1.000000

# %%
util.getCorrHeatMap(ds_hhprice);

# %%
#drop address
ds_hhprice_clean = ds_hhprice.drop('Address', axis=1)
ds_hhprice_clean
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population  high_price
# 0                             4.09     23086.800503       False
# 1                             3.09     40173.072174        True
# 2                             5.13     36882.159400       False
# 3                             3.26     34310.242831       False
# 4                             4.23     26354.109472       False
# ...                            ...              ...         ...
# 4995                          3.46     22837.361035       False
# 4996                          4.02     25616.115489        True
# 4997                          2.13     33266.145490       False
# 4998                          5.44     42625.620156       False
# 4999                          4.07     46501.283803       False
#
# [5000 rows x 6 columns]

# %% [markdown]
# # Implementando o modelo de classificação usando o SVM

# %%
from sklearn.model_selection import train_test_split
X = ds_hhprice_clean.drop('high_price', axis=1) #independent variables
y = ds_hhprice_clean['high_price'] #dependent variable

#splitting the dataset
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=1102)

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 3428 to 1581
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              4000 non-null   float64
#  1   Avg. Area House Age           4000 non-null   float64
#  2   Avg. Area Number of Rooms     4000 non-null   float64
#  3   Avg. Area Number of Bedrooms  4000 non-null   float64
#  4   Area Population               4000 non-null   float64
# dtypes: float64(5)
# memory usage: 187.5 KB

# %%
X_valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1493 to 1962
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              1000 non-null   float64
#  1   Avg. Area House Age           1000 non-null   float64
#  2   Avg. Area Number of Rooms     1000 non-null   float64
#  3   Avg. Area Number of Bedrooms  1000 non-null   float64
#  4   Area Population               1000 non-null   float64
# dtypes: float64(5)
# memory usage: 46.9 KB

# %% [markdown]
# # Testando o modelo com o cross-validation usando a métrica F1 Score

# %%
from sklearn import svm
clf = svm.SVC()
model = clf.fit(X_train, y_train)

from sklearn.model_selection import cross_val_score
valid_results = cross_val_score(model, X=X_valid, y=y_valid, scoring='f1', cv=10)
valid_results
# Out:
# array([0.61904762, 0.68292683, 0.61904762, 0.41860465, 0.58536585,
#        0.72340426, 0.68181818, 0.60465116, 0.625     , 0.5       ])

# %%
valid_results.mean()
# Out:
# 0.6059866172112887

# %% [markdown]
# # Gerando a Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix
import autoML

cf_matrix = confusion_matrix(y_valid, model.predict(X_valid))

autoML.getConfusionMatrixHeatMap(cf_matrix);

# %% [markdown]
# # Encapsulando a "receita de bolo" em uma classe AutoML

# %%
automl_house = autoML.AutoML(ds_hhprice, 'high_price')
automl_house.setAlgorithm(svm.SVC())
dfResults = automl_house.getResults()
dfResults
# Out:
#    algorithm                                           features n_features  \
# 0        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          4
# 1        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          5
# 2        SVC  (Avg. Area Income, Avg. Area House Age, Area P...          3
# 3        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          4
# 4        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          3
# 5        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          4
# 6        SVC  (Avg. Area Income, Avg. Area Number of Rooms, ...          3
# 7        SVC  (Avg. Area Income, Avg. Area Number of Rooms, ...          4
# 8        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          3
# 9        SVC  (Avg. Area Income, Avg. Area Number of Bedroom...          3
# 10       SVC  (Avg. Area Income, Avg. Area Number of Rooms, ...          3
# 11       SVC  (Avg. Area House Age, Avg. Area Number of Room...          3
# 12       SVC  (Avg. Area House Age, Avg. Area Number of Room...          4
# 13       SVC  (Avg. Area House Age, Avg. Area Number of Bedr...          3
# 14       SVC  (Avg. Area House Age, Avg. Area Number of Room...          3
# 15       SVC  (Avg. Area Number of Rooms, Avg. Area Number o...          3
#
#     train_time     mem_max        f1  accuracy   roc_auc  \
# 0     1.084147  211.445312  0.822167     0.910  0.970685
# 1     1.160217  211.707031  0.812659     0.908  0.968161
# 2     1.262047  211.136719  0.766522     0.887  0.934735
# 3     1.300413  213.179688  0.763477     0.883  0.944404
# 4     1.352081  211.843750  0.683621     0.856  0.897756
# 5     1.333790  212.648438  0.683503     0.855  0.913215
# 6     1.277325  223.070312  0.657386     0.845  0.884980
# 7     1.418516  210.847656  0.649855     0.839  0.898968
# 8     1.374318  212.066406  0.631741     0.842  0.876569
# 9     1.400650  224.683594  0.622211     0.832  0.869264
# 10    1.493006  226.640625  0.525103     0.798  0.846676
# 11    1.629403  231.484375  0.412489     0.772  0.765725
# 12    1.590140  226.003906  0.379934     0.764  0.783512
# 13    1.687493  231.929688  0.272010     0.761  0.733955
# 14    1.675031  233.136719  0.215689     0.760  0.686142
# 15    1.766401  235.308594  0.175924     0.745  0.653875
#
#            confusion_matrix
# 0    [[701, 38], [47, 214]]
# 1    [[700, 39], [48, 213]]
# 2    [[711, 28], [84, 177]]
# 3    [[704, 35], [70, 191]]
# 4    [[691, 48], [93, 168]]
# 5    [[692, 47], [94, 167]]
# 6   [[698, 41], [110, 151]]
# 7   [[695, 44], [106, 155]]
# 8   [[695, 44], [117, 144]]
# 9   [[708, 31], [129, 132]]
# 10  [[691, 48], [150, 111]]
# 11   [[695, 44], [172, 89]]
# 12   [[691, 48], [170, 91]]
# 13   [[703, 36], [193, 68]]
# 14   [[715, 24], [207, 54]]
# 15   [[721, 18], [226, 35]]

# %%
dfResults.describe()
# Out:
#        train_time     mem_max         f1   accuracy    roc_auc
# count   16.000000   16.000000  16.000000  16.000000  16.000000
# mean     1.425311  220.445801   0.567143   0.828563   0.851789
# std      0.198101    9.394219   0.212496   0.055314   0.098610
# min      1.084147  210.847656   0.175924   0.745000   0.653875
# 25%      1.294641  211.809570   0.404350   0.770000   0.779065
# 50%      1.387484  218.125000   0.640798   0.840500   0.880774
# 75%      1.599956  227.851562   0.703585   0.862750   0.918595
# max      1.766401  235.308594   0.822167   0.910000   0.970685

# %%
automl_house.getBestResult()
# Out:
# algorithm                                                         SVC
# features            (Avg. Area Income, Avg. Area House Age, Avg. A...
# n_features                                                          4
# train_time                                                   1.084147
# mem_max                                                    211.445312
# f1                                                           0.822167
# accuracy                                                         0.91
# roc_auc                                                      0.970685
# confusion_matrix                               [[701, 38], [47, 214]]
# Name: 0, dtype: object

# %%
automl_house.getBestResult()['features']
# Out:
# ('Avg. Area Income',
#  'Avg. Area House Age',
#  'Avg. Area Number of Rooms',
#  'Area Population')

# %%
automl_house.getBestConfusionMatrix()

# %%
automl_house.processAllFeatureCombinations()
dfResults_all = automl_house.getResults()
dfResults_all
# Out:
#    algorithm                                           features n_features  \
# 0        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          4
# 1        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          5
# 2        SVC  (Avg. Area Income, Avg. Area House Age, Area P...          3
# 3        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          4
# 4        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          3
# 5        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          4
# 6        SVC  (Avg. Area Income, Avg. Area Number of Rooms, ...          3
# 7        SVC  (Avg. Area Income, Avg. Area Number of Rooms, ...          4
# 8        SVC            (Avg. Area Income, Avg. Area House Age)          2
# 9        SVC  (Avg. Area Income, Avg. Area House Age, Avg. A...          3
# 10       SVC  (Avg. Area Income, Avg. Area Number of Bedroom...          3
# 11       SVC                (Avg. Area Income, Area Population)          2
# 12       SVC      (Avg. Area Income, Avg. Area Number of Rooms)          2
# 13       SVC  (Avg. Area Income, Avg. Area Number of Rooms, ...          3
# 14       SVC                                (Avg. Area Income,)          1
# 15       SVC   (Avg. Area Income, Avg. Area Number of Bedrooms)          2
# 16       SVC  (Avg. Area House Age, Avg. Area Number of Room...          3
# 17       SVC  (Avg. Area House Age, Avg. Area Number of Room...          4
# 18       SVC             (Avg. Area House Age, Area Population)          2
# 19       SVC   (Avg. Area House Age, Avg. Area Number of Rooms)          2
# 20       SVC  (Avg. Area House Age, Avg. Area Number of Bedr...          3
# 21       SVC       (Avg. Area Number of Rooms, Area Population)          2
# 22       SVC  (Avg. Area House Age, Avg. Area Number of Room...          3
# 23       SVC  (Avg. Area Number of Rooms, Avg. Area Number o...          3
# 24       SVC                             (Avg. Area House Age,)          1
# 25       SVC                                 (Area Population,)          1
# 26       SVC                       (Avg. Area Number of Rooms,)          1
# 27       SVC  (Avg. Area House Age, Avg. Area Number of Bedr...          2
# 28       SVC    (Avg. Area Number of Bedrooms, Area Population)          2
# 29       SVC  (Avg. Area Number of Rooms, Avg. Area Number o...          2
# 30       SVC                    (Avg. Area Number of Bedrooms,)          1
#
#     train_time     mem_max        f1  accuracy   roc_auc  \
# 0     1.080115  225.773438  0.822167     0.910  0.970685
# 1     1.158791  225.878906  0.812659     0.908  0.968161
# 2     1.240648  224.644531  0.766522     0.887  0.934735
# 3     1.203652  225.417969  0.763477     0.883  0.944404
# 4     1.260177  225.515625  0.683621     0.856  0.897756
# 5     1.294241  226.089844  0.683503     0.855  0.913215
# 6     1.312297  229.558594  0.657386     0.845  0.884980
# 7     1.283134  226.175781  0.649855     0.839  0.898968
# 8     1.316989  237.406250  0.647100     0.848  0.842198
# 9     1.408554  226.488281  0.631741     0.842  0.876569
# 10    1.327421  237.695312  0.622211     0.832  0.869264
# 11    1.312927  237.746094  0.603720     0.829  0.822212
# 12    1.376022  238.503906  0.552511     0.802  0.819181
# 13    1.347736  239.882812  0.525103     0.798  0.846676
# 14    1.513540  244.527344  0.519711     0.793  0.760802
# 15    1.491228  239.492188  0.474743     0.790  0.802650
# 16    1.520891  242.707031  0.412489     0.772  0.765725
# 17    1.456715  239.621094  0.379934     0.764  0.783512
# 18    1.560923  247.390625  0.327947     0.762  0.745729
# 19    1.622157  251.011719  0.291393     0.760  0.655796
# 20    1.478407  239.386719  0.272010     0.761  0.733955
# 21    1.799140  252.867188  0.237779     0.750  0.667930
# 22    1.541886  245.929688  0.215689     0.760  0.686142
# 23    1.656321  247.042969  0.175924     0.745  0.653875
# 24    2.113024  253.585938  0.171359     0.746  0.605920
# 25    2.026870  252.839844  0.134380     0.736  0.588952
# 26    1.990407  249.691406  0.116724     0.744  0.548817
# 27    1.801409  251.230469  0.096980     0.744  0.637728
# 28    1.756723  251.246094  0.053729     0.734  0.626201
# 29    2.049241  253.964844  0.007273     0.737  0.581025
# 30    1.421565  239.515625  0.000000     0.739  0.507012
#
#            confusion_matrix
# 0    [[701, 38], [47, 214]]
# 1    [[700, 39], [48, 213]]
# 2    [[711, 28], [84, 177]]
# 3    [[704, 35], [70, 191]]
# 4    [[691, 48], [93, 168]]
# 5    [[692, 47], [94, 167]]
# 6   [[698, 41], [110, 151]]
# 7   [[695, 44], [106, 155]]
# 8   [[704, 35], [118, 143]]
# 9   [[695, 44], [117, 144]]
# 10  [[708, 31], [129, 132]]
# 11  [[702, 37], [135, 126]]
# 12  [[685, 54], [137, 124]]
# 13  [[691, 48], [150, 111]]
# 14   [[694, 45], [168, 93]]
# 15   [[704, 35], [171, 90]]
# 16   [[695, 44], [172, 89]]
# 17   [[691, 48], [170, 91]]
# 18   [[704, 35], [194, 67]]
# 19   [[699, 40], [190, 71]]
# 20   [[703, 36], [193, 68]]
# 21   [[717, 22], [209, 52]]
# 22   [[715, 24], [207, 54]]
# 23   [[721, 18], [226, 35]]
# 24   [[720, 19], [235, 26]]
# 25   [[726, 13], [241, 20]]
# 26     [[736, 3], [254, 7]]
# 27   [[717, 22], [231, 30]]
# 28   [[725, 14], [245, 16]]
# 29     [[739, 0], [261, 0]]
# 30     [[739, 0], [261, 0]]

# %%
automl_house.getBestResult()
# Out:
# algorithm                                                         SVC
# features            (Avg. Area Income, Avg. Area House Age, Avg. A...
# n_features                                                          4
# train_time                                                   1.080115
# mem_max                                                    225.773438
# f1                                                           0.822167
# accuracy                                                         0.91
# roc_auc                                                      0.970685
# confusion_matrix                               [[701, 38], [47, 214]]
# Name: 0, dtype: object

# %%
automl_house.getBestConfusionMatrix()

# %%
dfResults_all.describe()
# Out:
#        train_time     mem_max         f1   accuracy    roc_auc
# count   31.000000   31.000000  31.000000  31.000000  31.000000
# mean     1.507198  239.639617   0.429343   0.799065   0.769057
# std      0.275035   10.161336   0.259210   0.055705   0.134175
# min      1.080115  224.644531   0.000000   0.734000   0.507012
# 25%      1.312612  228.023438   0.195806   0.748000   0.654836
# 50%      1.456715  239.515625   0.474743   0.790000   0.783512
# 75%      1.639239  248.541016   0.648478   0.843500   0.880774
# max      2.113024  253.964844   0.822167   0.910000   0.970685

# %%
import pandas as pd
dfResults_all.rename(columns={'train_time':'train_time_all','mem_max':'mem_max_all'
                              ,'f1':'f1_all','accuracy':'accuracy_all', 'roc_auc':'roc_auc_all'}, inplace=True)
pd.concat([dfResults.reset_index().drop('index', axis=1)
           , dfResults_all.reset_index().drop('index', axis=1)], axis=1).describe()
# Out:
#        train_time     mem_max         f1   accuracy    roc_auc  \
# count   16.000000   16.000000  16.000000  16.000000  16.000000
# mean     1.425311  220.445801   0.567143   0.828563   0.851789
# std      0.198101    9.394219   0.212496   0.055314   0.098610
# min      1.084147  210.847656   0.175924   0.745000   0.653875
# 25%      1.294641  211.809570   0.404350   0.770000   0.779065
# 50%      1.387484  218.125000   0.640798   0.840500   0.880774
# 75%      1.599956  227.851562   0.703585   0.862750   0.918595
# max      1.766401  235.308594   0.822167   0.910000   0.970685
#
#        train_time_all  mem_max_all     f1_all  accuracy_all  roc_auc_all
# count       31.000000    31.000000  31.000000     31.000000    31.000000
# mean         1.507198   239.639617   0.429343      0.799065     0.769057
# std          0.275035    10.161336   0.259210      0.055705     0.134175
# min          1.080115   224.644531   0.000000      0.734000     0.507012
# 25%          1.312612   228.023438   0.195806      0.748000     0.654836
# 50%          1.456715   239.515625   0.474743      0.790000     0.783512
# 75%          1.639239   248.541016   0.648478      0.843500     0.880774
# max          2.113024   253.964844   0.822167      0.910000     0.970685

# %%
dfGroupBy_features = dfResults_all.groupby('n_features').mean()
dfGroupBy_features
# Out:
#             train_time_all  mem_max_all    f1_all  accuracy_all  roc_auc_all
# n_features
# 1                 1.813081   248.032031  0.188435        0.7516     0.602301
# 2                 1.608676   246.085938  0.329318        0.7756     0.720065
# 3                 1.409434   235.885156  0.496270        0.8098     0.814968
# 4                 1.263571   228.615625  0.659787        0.8502     0.902157
# 5                 1.158791   225.878906  0.812659        0.9080     0.968161

# %%
dfGroupBy_features['train_time_all'].plot.bar();

# %%
dfGroupBy_features['mem_max_all'].plot.bar();

# %%
dfGroupBy_features['f1_all'].plot.bar();

# %%
dfGroupBy_features['accuracy_all'].plot.bar();

# %%
dfGroupBy_features['roc_auc_all'].plot.bar();
